# %%
import itertools
import pandas as pd
import numpy as np
from tqdm import tqdm  # Progress tracking
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from itertools import combinations
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv('/home/duyle/Rice_photos/features_extracted/moments/bc_15_randomsearchcv.csv')

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None,'display.max_colwidth', None):
    display(df.sort_values(by='Accuracy', ascending=False))

# %%
datasets = ['BC-15','Huongthom', 'Nep87','Q5','Thien_uu','Xi23']

# %%
df = pd.read_csv('/home/duyle/Rice_photos/features_extracted/moments/testnewcontour.csv')

# %%
basic_features = ["area", "length", "width", "ratio", "major_axis_length", "minor_axis_length", "convex_hull_area",
                  "convex_hull_perimeter","mean_r","mean_g","mean_b","red_sqr","green_sqr","blue_sqr","texture_mean",
                  "texture_std","texture_uniformity","texture_third_moment"]
enhanced_color_features = ['mean_h','mean_s','mean_v','std_h','std_s','std_v','hue_sqr','sat_sqr',
'val_sqr','mean_y','mean_cr','mean_cb','std_y','std_cr','std_cb','y_sqr','cr_sqr','cb_sqr',
'mean_l','mean_a','mean_b','std_l','std_a','std_b_lab','l_sqr','a_sqr','b_lab_sqr']

zernike_features = [col for col in df.columns if col.startswith("zernike_")]
color_features = [col for col in df.columns if col.startswith("csd_")]
lbp_features = [col for col in df.columns if col.startswith("LBP_")]
glcm_features = [col for col in df.columns if col.startswith("GLCM_")]
gist_features = [col for col in df.columns if col.startswith("GIST_")]
edge_features = [col for col in df.columns if col.startswith("edge_energy")]

# %%
feature_groups = {
    "Basic": basic_features,
    "Enhanced Color": enhanced_color_features,
    "Zernike moments": zernike_features,
    "LBP": lbp_features,
    "GLCM": glcm_features,
    # "GIST": gist_features,
    "Edge":edge_features
}

# %%
feature_combinations = []
for r in range(3, len(feature_groups) + 1):  # From 1 feature group up to all
    for combo in combinations(feature_groups.keys(), r):
        feature_combinations.append(combo)

# %%
models = {
    "K-Nearest Neighbors": KNeighborsClassifier(n_neighbors=31),
    "Support Vector Machine": SVC(kernel='rbf', C=7.742636826811277,gamma = 'auto'),
    "Random Forest": RandomForestClassifier(n_estimators=200, max_depth=20, min_samples_split=2, min_samples_leaf=1, bootstrap=True)
}

# %%
all_results = []

# %%
for data in datasets:
    df=pd.read_csv(f'/home/duyle/Rice_photos/features_extracted/moments/all_with_zernike_pluscolor_enahnced_edge_{data}.csv')
    for feature_combo in feature_combinations:
        selected_features = []
        
        # Combine selected feature groups
        for group in feature_combo:
            selected_features.extend(feature_groups[group])

        # Ensure 'Label' column is included
        df_selected = df[selected_features + ["Label"]]

        X = df_selected.drop(columns=['Label'])
        y = df_selected['Label']

        # Normalize the features
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)

        X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.33, random_state=42, stratify=y)


        for name, model in models.items():
            model.fit(X_train, y_train)
            y_pred = model.predict(X_test)

            accuracy = accuracy_score(y_test, y_pred)
            precision = precision_score(y_test, y_pred, average='weighted')
            recall = recall_score(y_test, y_pred, average='weighted')
            f1 = f1_score(y_test, y_pred, average='weighted')
            cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy')

            all_results.append({
                "Model": name,
                "Dataset": data,
                "Feature Combination": "+".join(feature_combo),
                "Accuracy": accuracy,
                "Precision": precision,
                "Recall": recall,
                "F1 Score": f1,
                "CV_scores(5fold)": np.mean(cv_scores)
            })

# %%
all_results_df = pd.DataFrame(all_results)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from statsmodels.stats.outliers_influence import variance_inflation_factor

    # 1. Correlation Matrix with Heatmap
def plot_correlation_matrix(X):
    plt.figure(figsize=(12, 8))
    correlation_matrix = X.corr()
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
    plt.title('Feature Correlation Matrix')
    plt.tight_layout()
    plt.show()
    
    # Return highly correlated feature pairs (correlation > 0.8)
    high_corr = np.where(np.abs(correlation_matrix) > 0.8)
    high_corr = [(correlation_matrix.index[x], correlation_matrix.columns[y], correlation_matrix.iloc[x, y]) 
                 for x, y in zip(*high_corr) if x != y and x < y]
    return high_corr

# 2. VIF (Variance Inflation Factor)
def calculate_vif(X):
    vif_data = pd.DataFrame()
    vif_data["Feature"] = X.columns
    vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    return vif_data.sort_values('VIF', ascending=False)

# Using your existing X dataframe (features only, no target variable)
X = df_selected.drop(columns=['Label'])

# 1. Check correlation matrix
high_correlations = plot_correlation_matrix(X)
print("\nHighly correlated feature pairs (>0.8):")
for feat1, feat2, corr in high_correlations:
    print(f"{feat1} -- {feat2}: {corr:.3f}")

# 2. Check VIF scores
vif_scores = calculate_vif(X)
print("\nVIF Scores (>5 may indicate multicollinearity):")
print(vif_scores)
# Out:
# Highly correlated feature pairs (>0.8):
# area -- convex_hull_area: 0.993
# area -- LBP_3: 0.861
# area -- LBP_6: 0.862
# length -- major_axis_length: 0.852
# length -- convex_hull_perimeter: 0.942
# width -- ratio: -0.906
# width -- minor_axis_length: 0.956
# width -- zernike_6: -0.815
# width -- zernike_7: -0.835
# width -- zernike_8: -0.814
# width -- zernike_12: -0.897
# width -- zernike_13: -0.874
# width -- zernike_14: -0.878
# width -- zernike_15: -0.808
# width -- zernike_22: -0.886
# width -- zernike_23: -0.883
# ratio -- minor_axis_length: -0.841
# ratio -- zernike_3: 0.817
# ratio -- zernike_6: 0.822
# ratio -- zernike_7: 0.881
# ratio -- zernike_8: 0.840
# ratio -- zernike_12: 0.932
# ratio -- zernike_13: 0.914
# ratio -- zernike_14: 0.919
# ratio -- zernike_15: 0.834
# ratio -- zernike_20: 0.815
# ratio -- zernike_22: 0.927
# ratio -- zernike_23: 0.923
# minor_axis_length -- zernike_6: -0.842
# minor_axis_length -- zernike_12: -0.892
# minor_axis_length -- zernike_13: -0.863
# minor_axis_length -- zernike_14: -0.857
# minor_axis_length -- zernike_15: -0.816
# minor_axis_length -- zernike_22: -0.888
# minor_axis_length -- zernike_23: -0.885
# convex_hull_area -- LBP_3: 0.865
# convex_hull_area -- LBP_6: 0.862
# mean_r -- mean_g: 0.898
# mean_r -- red_sqr: 1.000
# mean_r -- green_sqr: 0.899
# mean_r -- texture_mean: 0.928
# mean_r -- mean_v: 1.000
# mean_r -- std_v: -0.820
# mean_r -- val_sqr: 1.000
# mean_r -- mean_y: 0.928
# mean_r -- y_sqr: 0.929
# mean_r -- mean_l: 0.937
# mean_r -- std_l: -0.800
# mean_r -- l_sqr: 0.937
# mean_g -- red_sqr: 0.898
# mean_g -- green_sqr: 1.000
# mean_g -- texture_mean: 0.995
# mean_g -- texture_std: -0.886
# mean_g -- mean_v: 0.899
# mean_g -- val_sqr: 0.899
# mean_g -- mean_y: 0.995
# mean_g -- std_y: -0.886
# mean_g -- y_sqr: 0.995
# mean_g -- mean_l: 0.995
# mean_g -- std_l: -0.889
# mean_g -- std_a: -0.833
# mean_g -- l_sqr: 0.995
# mean_b -- blue_sqr: 1.000
# mean_b -- mean_s: -0.924
# mean_b -- std_s: -0.806
# mean_b -- sat_sqr: -0.923
# mean_b -- mean_b: 1.000
# red_sqr -- green_sqr: 0.899
# red_sqr -- texture_mean: 0.928
# red_sqr -- mean_v: 1.000
# red_sqr -- std_v: -0.823
# red_sqr -- val_sqr: 1.000
# red_sqr -- mean_y: 0.928
# red_sqr -- y_sqr: 0.929
# red_sqr -- mean_l: 0.937
# red_sqr -- std_l: -0.802
# red_sqr -- l_sqr: 0.937
# green_sqr -- texture_mean: 0.995
# green_sqr -- texture_std: -0.887
# green_sqr -- mean_v: 0.899
# green_sqr -- val_sqr: 0.899
# green_sqr -- mean_y: 0.995
# green_sqr -- std_y: -0.887
# green_sqr -- y_sqr: 0.995
# green_sqr -- mean_l: 0.995
# green_sqr -- std_l: -0.890
# green_sqr -- std_a: -0.833
# green_sqr -- l_sqr: 0.995
# blue_sqr -- mean_s: -0.924
# blue_sqr -- std_s: -0.805
# blue_sqr -- sat_sqr: -0.923
# blue_sqr -- mean_b: 1.000
# texture_mean -- texture_std: -0.872
# texture_mean -- mean_v: 0.928
# texture_mean -- val_sqr: 0.928
# texture_mean -- mean_y: 1.000
# texture_mean -- std_y: -0.872
# texture_mean -- y_sqr: 1.000
# texture_mean -- mean_l: 0.999
# texture_mean -- std_l: -0.876
# texture_mean -- l_sqr: 0.998
# texture_std -- std_v: 0.915
# texture_std -- mean_y: -0.872
# texture_std -- std_y: 1.000
# texture_std -- y_sqr: -0.873
# texture_std -- mean_l: -0.879
# texture_std -- std_l: 0.998
# texture_std -- std_a: 0.861
# texture_std -- l_sqr: -0.879
# texture_std -- GLCM_1: 0.822
# texture_std -- GLCM_2: 0.866
# texture_std -- GLCM_3: 0.823
# texture_uniformity -- GLCM_8: 0.876
# texture_uniformity -- GLCM_9: 0.878
# texture_uniformity -- GLCM_10: 0.863
# texture_uniformity -- GLCM_11: 0.879
# mean_h -- hue_sqr: 1.000
# mean_h -- mean_a: -0.837
# mean_h -- a_sqr: -0.837
# mean_s -- sat_sqr: 1.000
# mean_s -- mean_cr: 0.880
# mean_s -- cr_sqr: 0.880
# mean_s -- mean_b: -0.924
# mean_v -- std_v: -0.820
# mean_v -- val_sqr: 1.000
# mean_v -- mean_y: 0.929
# mean_v -- y_sqr: 0.929
# mean_v -- mean_l: 0.937
# mean_v -- std_l: -0.800
# mean_v -- l_sqr: 0.938
# std_s -- std_cr: 0.927
# std_s -- mean_b: -0.806
# std_s -- std_a: 0.821
# std_v -- val_sqr: -0.823
# std_v -- std_y: 0.915
# std_v -- mean_l: -0.808
# std_v -- std_l: 0.933
# std_v -- l_sqr: -0.811
# std_v -- GLCM_1: 0.827
# std_v -- GLCM_2: 0.865
# std_v -- GLCM_3: 0.828
# hue_sqr -- mean_a: -0.836
# hue_sqr -- a_sqr: -0.836
# sat_sqr -- mean_cr: 0.881
# sat_sqr -- cr_sqr: 0.881
# sat_sqr -- mean_b: -0.923
# val_sqr -- mean_y: 0.928
# val_sqr -- y_sqr: 0.929
# val_sqr -- mean_l: 0.937
# val_sqr -- std_l: -0.802
# val_sqr -- l_sqr: 0.938
# mean_y -- std_y: -0.872
# mean_y -- y_sqr: 1.000
# mean_y -- mean_l: 0.999
# mean_y -- std_l: -0.876
# mean_y -- l_sqr: 0.998
# mean_cr -- std_cr: 0.824
# mean_cr -- cr_sqr: 1.000
# mean_cr -- mean_a: 0.818
# mean_cr -- a_sqr: 0.819
# mean_cb -- cb_sqr: 1.000
# mean_cb -- b_lab_sqr: -0.997
# std_y -- y_sqr: -0.873
# std_y -- mean_l: -0.879
# std_y -- std_l: 0.998
# std_y -- std_a: 0.861
# std_y -- l_sqr: -0.879
# std_y -- GLCM_1: 0.822
# std_y -- GLCM_2: 0.866
# std_y -- GLCM_3: 0.823
# std_cr -- cr_sqr: 0.824
# std_cr -- mean_a: 0.869
# std_cr -- std_a: 0.890
# std_cr -- a_sqr: 0.869
# std_cb -- std_b_lab: 0.994
# y_sqr -- mean_l: 0.999
# y_sqr -- std_l: -0.878
# y_sqr -- l_sqr: 0.999
# cr_sqr -- mean_a: 0.819
# cr_sqr -- a_sqr: 0.819
# cb_sqr -- b_lab_sqr: -0.997
# mean_l -- std_l: -0.885
# mean_l -- l_sqr: 1.000
# mean_l -- GLCM_2: -0.801
# mean_a -- std_a: 0.932
# mean_a -- a_sqr: 1.000
# std_l -- std_a: 0.845
# std_l -- l_sqr: -0.886
# std_l -- GLCM_1: 0.831
# std_l -- GLCM_2: 0.875
# std_l -- GLCM_3: 0.833
# std_a -- a_sqr: 0.932
# l_sqr -- GLCM_2: -0.803
# zernike_3 -- zernike_7: 0.868
# zernike_3 -- zernike_8: 0.971
# zernike_3 -- zernike_12: 0.840
# zernike_3 -- zernike_14: 0.896
# zernike_3 -- zernike_15: 0.901
# zernike_3 -- zernike_23: 0.866
# zernike_5 -- zernike_9: 0.801
# zernike_5 -- zernike_11: 0.960
# zernike_5 -- zernike_18: 0.853
# zernike_5 -- zernike_19: 0.885
# zernike_6 -- zernike_7: 0.872
# zernike_6 -- zernike_12: 0.924
# zernike_6 -- zernike_13: 0.952
# zernike_6 -- zernike_14: 0.884
# zernike_6 -- zernike_22: 0.892
# zernike_6 -- zernike_23: 0.894
# zernike_7 -- zernike_8: 0.871
# zernike_7 -- zernike_12: 0.942
# zernike_7 -- zernike_13: 0.965
# zernike_7 -- zernike_14: 0.981
# zernike_7 -- zernike_15: 0.817
# zernike_7 -- zernike_22: 0.902
# zernike_7 -- zernike_23: 0.945
# zernike_8 -- zernike_12: 0.893
# zernike_8 -- zernike_13: 0.838
# zernike_8 -- zernike_14: 0.922
# zernike_8 -- zernike_15: 0.972
# zernike_8 -- zernike_22: 0.826
# zernike_8 -- zernike_23: 0.922
# zernike_8 -- zernike_24: 0.885
# zernike_9 -- zernike_11: 0.822
# zernike_9 -- zernike_18: 0.863
# zernike_9 -- zernike_19: 0.810
# zernike_11 -- zernike_18: 0.813
# zernike_11 -- zernike_19: 0.978
# zernike_12 -- zernike_13: 0.968
# zernike_12 -- zernike_14: 0.975
# zernike_12 -- zernike_15: 0.886
# zernike_12 -- zernike_22: 0.967
# zernike_12 -- zernike_23: 0.979
# zernike_12 -- zernike_24: 0.811
# zernike_13 -- zernike_14: 0.964
# zernike_13 -- zernike_15: 0.825
# zernike_13 -- zernike_22: 0.951
# zernike_13 -- zernike_23: 0.952
# zernike_14 -- zernike_15: 0.889
# zernike_14 -- zernike_22: 0.935
# zernike_14 -- zernike_23: 0.987
# zernike_15 -- zernike_22: 0.823
# zernike_15 -- zernike_23: 0.919
# zernike_15 -- zernike_24: 0.965
# zernike_20 -- zernike_21: 0.971
# zernike_20 -- zernike_22: 0.864
# zernike_22 -- zernike_23: 0.944
# zernike_23 -- zernike_24: 0.850
# LBP_0 -- LBP_1: 0.831
# LBP_0 -- LBP_2: 0.896
# LBP_1 -- LBP_7: 0.879
# LBP_3 -- LBP_5: 0.832
# LBP_3 -- LBP_6: 0.812
# LBP_4 -- LBP_5: 0.822
# GLCM_1 -- GLCM_2: 0.954
# GLCM_1 -- GLCM_3: 0.848
# GLCM_2 -- GLCM_3: 0.955
# GLCM_5 -- GLCM_6: 0.845
# GLCM_6 -- GLCM_7: 0.845
# GLCM_8 -- GLCM_9: 0.983
# GLCM_8 -- GLCM_10: 0.967
# GLCM_8 -- GLCM_11: 0.984
# GLCM_9 -- GLCM_10: 0.993
# GLCM_9 -- GLCM_11: 0.994
# GLCM_10 -- GLCM_11: 0.993
# GLCM_12 -- GLCM_13: 0.889
# GLCM_12 -- GLCM_14: 0.816
# GLCM_12 -- GLCM_15: 0.887
# GLCM_13 -- GLCM_14: 0.963
# GLCM_13 -- GLCM_15: 0.948
# GLCM_14 -- GLCM_15: 0.965
# edge_energy_vertical -- edge_energy_horizontal: -0.953
# edge_energy_horizontal -- edge_energy_non_directional: 0.850
# edge_energy_diag_45 -- edge_energy_non_directional: -0.826
# edge_energy_diag_135 -- edge_energy_non_directional: -0.828
#
# VIF Scores (>5 may indicate multicollinearity):
#                          Feature           VIF
# 38                        mean_b  8.188363e+14
# 10                        mean_b  4.503600e+14
# 97        edge_energy_horizontal  1.402772e+12
# 96          edge_energy_vertical  1.212111e+12
# 100  edge_energy_non_directional  1.111191e+11
# 99          edge_energy_diag_135  1.077855e+11
# 98           edge_energy_diag_45  1.060856e+11
# 27                        mean_y  8.841278e+08
# 14                  texture_mean  6.038584e+08
# 30                         std_y  5.396006e+08
# 15                   texture_std  5.392552e+08
# 8                         mean_r  3.179891e+08
# 11                       red_sqr  3.122114e+08
# 20                        mean_v  3.105175e+08
# 26                       val_sqr  3.067600e+08
# 33                         y_sqr  1.878715e+08
# 9                         mean_g  1.066888e+08
# 12                     green_sqr  1.047099e+08
# 36                        mean_l  2.124789e+07
# 42                         l_sqr  2.004281e+07
# 34                        cr_sqr  6.836383e+06
# 28                       mean_cr  6.826150e+06
# 43                         a_sqr  5.182401e+06
# 37                        mean_a  5.066848e+06
# 29                       mean_cb  2.580976e+06
# 35                        cb_sqr  2.032791e+06
# 13                      blue_sqr  9.514011e+05
# 19                        mean_s  1.902426e+05
# 25                       sat_sqr  1.838319e+05
# 48                     zernike_3  1.571002e+05
# 52                     zernike_7  9.876180e+04
# 53                     zernike_8  6.309162e+04
# 18                        mean_h  4.806809e+04
# 24                       hue_sqr  4.712896e+04
# 47                     zernike_2  4.178063e+04
# 44                     b_lab_sqr  3.490955e+04
# 39                         std_l  3.364567e+04
# 51                     zernike_6  2.609952e+04
# 60                    zernike_15  1.350601e+04
# 59                    zernike_14  1.047392e+04
# 41                     std_b_lab  9.089876e+03
# 32                        std_cb  8.163317e+03
# 58                    zernike_13  5.063954e+03
# 22                         std_s  3.705323e+03
# 82                        GLCM_2  2.430478e+03
# 31                        std_cr  2.110424e+03
# 69                    zernike_24  1.867907e+03
# 68                    zernike_23  1.291581e+03
# 56                    zernike_11  1.172211e+03
# 83                        GLCM_3  8.061274e+02
# 81                        GLCM_1  8.002400e+02
# 23                         std_v  7.764542e+02
# 86                        GLCM_6  6.746487e+02
# 91                       GLCM_11  5.728112e+02
# 89                        GLCM_9  5.460707e+02
# 64                    zernike_19  5.073731e+02
# 6               convex_hull_area  3.786399e+02
# 40                         std_a  3.600381e+02
# 0                           area  3.457889e+02
# 2                          width  3.319452e+02
# 90                       GLCM_10  3.153353e+02
# 87                        GLCM_7  2.995046e+02
# 85                        GLCM_5  2.967737e+02
# 1                         length  2.956640e+02
# 3                          ratio  2.880381e+02
# 7          convex_hull_perimeter  2.609912e+02
# 57                    zernike_12  2.558435e+02
# 50                     zernike_5  2.259194e+02
# 88                        GLCM_8  1.884335e+02
# 67                    zernike_22  1.282560e+02
# 80                        GLCM_0  1.219180e+02
# 21                         std_h  1.084397e+02
# 5              minor_axis_length  9.873994e+01
# 95                       GLCM_15  6.856477e+01
# 84                        GLCM_4  6.601034e+01
# 65                    zernike_20  6.592443e+01
# 93                       GLCM_13  6.457946e+01
# 66                    zernike_21  6.331958e+01
# 94                       GLCM_14  6.141229e+01
# 4              major_axis_length  5.362987e+01
# 92                       GLCM_12  3.266832e+01
# 17          texture_third_moment  3.226915e+01
# 75                         LBP_5  2.679309e+01
# 74                         LBP_4  2.228131e+01
# 16            texture_uniformity  2.079770e+01
# 63                    zernike_18  1.980249e+01
# 73                         LBP_3  1.894088e+01
# 49                     zernike_4  1.855985e+01
# 54                     zernike_9  1.814428e+01
# 72                         LBP_2  1.670844e+01
# 78                         LBP_8  1.397877e+01
# 70                         LBP_0  1.395063e+01
# 77                         LBP_7  1.378418e+01
# 71                         LBP_1  1.309458e+01
# 79                         LBP_9  1.230327e+01
# 76                         LBP_6  1.134400e+01
# 46                     zernike_1  4.292487e+00
# 61                    zernike_16  3.603968e+00
# 62                    zernike_17  3.403015e+00
# 55                    zernike_10  2.911399e+00
# 45                     zernike_0  1.449452e-10
