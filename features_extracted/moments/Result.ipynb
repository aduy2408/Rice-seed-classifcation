# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("combined_output.csv")
cols = df.columns
cols
# Out:
# Index(['Model', 'Dataset', 'Feature Combination', 'Best Params', 'Accuracy',
#        'Precision', 'Recall', 'F1 Score', 'CV_scores(5fold)'],
#       dtype='object')

# %%
df
# Out:
#                        Model Dataset    Feature Combination  \
# 0        K-Nearest Neighbors   BC-15   Basic+Enhanced Color
# 1     Support Vector Machine   BC-15   Basic+Enhanced Color
# 2              Random Forest   BC-15   Basic+Enhanced Color
# 3        K-Nearest Neighbors   BC-15  Basic+Zernike moments
# 4     Support Vector Machine   BC-15  Basic+Zernike moments
# ...                      ...     ...                    ...
# 1058     K-Nearest Neighbors    Xi23   Basic+Enhanced Color
# 1059  Support Vector Machine    Xi23   Basic+Enhanced Color
# 1060           Random Forest    Xi23   Basic+Enhanced Color
# 1061     K-Nearest Neighbors    Xi23  Basic+Zernike moments
# 1062  Support Vector Machine    Xi23  Basic+Zernike moments
#
#                                             Best Params  Accuracy  Precision  \
# 0     {'weights': 'distance', 'n_neighbors': 11, 'me...  0.885502   0.892514
# 1     {'kernel': 'rbf', 'gamma': 'auto', 'C': 7.7426...  0.928336   0.929771
# 2     {'n_estimators': 200, 'min_samples_split': 2, ...  0.913509   0.914896
# 3     {'weights': 'distance', 'n_neighbors': 11, 'me...  0.878913   0.889295
# 4     {'kernel': 'rbf', 'gamma': 'scale', 'C': 2.154...  0.922570   0.924069
# ...                                                 ...       ...        ...
# 1058  {'weights': 'distance', 'n_neighbors': 11, 'me...  0.933480   0.933678
# 1059  {'kernel': 'rbf', 'gamma': 'auto', 'C': 7.7426...  0.956871   0.956952
# 1060  {'n_estimators': 200, 'min_samples_split': 5, ...  0.937865   0.938517
# 1061  {'weights': 'uniform', 'n_neighbors': 9, 'metr...  0.929094   0.929745
# 1062  {'kernel': 'rbf', 'gamma': 'auto', 'C': 7.7426...  0.965643   0.965664
#
#         Recall  F1 Score  CV_scores(5fold)
# 0     0.885502  0.885003          0.879820
# 1     0.928336  0.928280          0.927725
# 2     0.913509  0.913441          0.899307
# 3     0.878913  0.878119          0.876574
# 4     0.922570  0.922506          0.935038
# ...        ...       ...               ...
# 1058  0.933480  0.933397          0.926174
# 1059  0.956871  0.956887          0.960390
# 1060  0.937865  0.937926          0.939498
# 1061  0.929094  0.928936          0.919335
# 1062  0.965643  0.965649          0.964709
#
# [1063 rows x 9 columns]

# %%
df = df.rename(columns={'Feature Combination':'Feature','Dataset':'Rice Seed','F1 Score':'F1-score'})

# %%
feature = df["Feature"].unique()
feature
# Out:
# array(['Basic+Enhanced Color', 'Basic+Zernike moments', 'Basic+LBP',
#        'Basic+GLCM', 'Basic+Edge', 'Enhanced Color+Zernike moments',
#        'Enhanced Color+LBP', 'Enhanced Color+GLCM', 'Enhanced Color+Edge',
#        'Zernike moments+LBP', 'Zernike moments+GLCM',
#        'Zernike moments+Edge', 'LBP+GLCM', 'LBP+Edge', 'GLCM+Edge',
#        'Basic+Enhanced Color+Zernike moments', 'Basic+Enhanced Color+LBP',
#        'Basic+Enhanced Color+GLCM', 'Basic+Enhanced Color+Edge',
#        'Basic+Zernike moments+LBP', 'Basic+Zernike moments+GLCM',
#        'Basic+Zernike moments+Edge', 'Basic+LBP+GLCM', 'Basic+LBP+Edge',
#        'Basic+GLCM+Edge', 'Enhanced Color+Zernike moments+LBP',
#        'Enhanced Color+Zernike moments+GLCM',
#        'Enhanced Color+Zernike moments+Edge', 'Enhanced Color+LBP+GLCM',
#        'Enhanced Color+LBP+Edge', 'Enhanced Color+GLCM+Edge',
#        'Zernike moments+LBP+GLCM', 'Zernike moments+LBP+Edge',
#        'Zernike moments+GLCM+Edge', 'LBP+GLCM+Edge',
#        'Basic+Enhanced Color+Zernike moments+LBP',
#        'Basic+Enhanced Color+Zernike moments+GLCM',
#        'Basic+Enhanced Color+Zernike moments+Edge',
#        'Basic+Enhanced Color+LBP+GLCM', 'Basic+Enhanced Color+LBP+Edge',
#        'Basic+Enhanced Color+GLCM+Edge', 'Basic+Zernike moments+LBP+GLCM',
#        'Basic+Zernike moments+LBP+Edge',
#        'Basic+Zernike moments+GLCM+Edge', 'Basic+LBP+GLCM+Edge',
#        'Enhanced Color+Zernike moments+LBP+GLCM',
#        'Enhanced Color+Zernike moments+LBP+Edge',
#        'Enhanced Color+Zernike moments+GLCM+Edge',
#        'Enhanced Color+LBP+GLCM+Edge', 'Zernike moments+LBP+GLCM+Edge',
#        'Basic+Enhanced Color+Zernike moments+LBP+GLCM',
#        'Basic+Enhanced Color+Zernike moments+LBP+Edge',
#        'Basic+Enhanced Color+Zernike moments+GLCM+Edge',
#        'Basic+Enhanced Color+LBP+GLCM+Edge',
#        'Basic+Zernike moments+LBP+GLCM+Edge',
#        'Enhanced Color+Zernike moments+LBP+GLCM+Edge',
#        'Basic+Enhanced Color+Zernike moments+LBP+GLCM+Edge'], dtype=object)

# %%
group_feature = df.groupby("Feature")

# %%
group_feature.get_group("Basic+Enhanced Color+Zernike moments+Edge")
# Out:
#                        Model  Rice Seed  \
# 111      K-Nearest Neighbors      BC-15
# 112   Support Vector Machine      BC-15
# 113            Random Forest      BC-15
# 314      K-Nearest Neighbors  Huongthom
# 315   Support Vector Machine  Huongthom
# 316            Random Forest  Huongthom
# 485      K-Nearest Neighbors      Nep87
# 486   Support Vector Machine      Nep87
# 487            Random Forest      Nep87
# 656      K-Nearest Neighbors       Xi23
# 657   Support Vector Machine       Xi23
# 658            Random Forest       Xi23
# 827      K-Nearest Neighbors         Q5
# 828   Support Vector Machine         Q5
# 829            Random Forest         Q5
# 998      K-Nearest Neighbors   Thien_uu
# 999   Support Vector Machine   Thien_uu
# 1000           Random Forest   Thien_uu
#
#                                         Feature  \
# 111   Basic+Enhanced Color+Zernike moments+Edge
# 112   Basic+Enhanced Color+Zernike moments+Edge
# 113   Basic+Enhanced Color+Zernike moments+Edge
# 314   Basic+Enhanced Color+Zernike moments+Edge
# 315   Basic+Enhanced Color+Zernike moments+Edge
# 316   Basic+Enhanced Color+Zernike moments+Edge
# 485   Basic+Enhanced Color+Zernike moments+Edge
# 486   Basic+Enhanced Color+Zernike moments+Edge
# 487   Basic+Enhanced Color+Zernike moments+Edge
# 656   Basic+Enhanced Color+Zernike moments+Edge
# 657   Basic+Enhanced Color+Zernike moments+Edge
# 658   Basic+Enhanced Color+Zernike moments+Edge
# 827   Basic+Enhanced Color+Zernike moments+Edge
# 828   Basic+Enhanced Color+Zernike moments+Edge
# 829   Basic+Enhanced Color+Zernike moments+Edge
# 998   Basic+Enhanced Color+Zernike moments+Edge
# 999   Basic+Enhanced Color+Zernike moments+Edge
# 1000  Basic+Enhanced Color+Zernike moments+Edge
#
#                                             Best Params  Accuracy  Precision  \
# 111   {'weights': 'distance', 'n_neighbors': 11, 'me...  0.891269   0.899306
# 112   {'kernel': 'rbf', 'gamma': 'auto', 'C': 7.7426...  0.940692   0.941001
# 113   {'n_estimators': 300, 'min_samples_split': 2, ...  0.912685   0.914150
# 314   {'weights': 'distance', 'n_neighbors': 11, 'me...  0.945985   0.946350
# 315   {'kernel': 'rbf', 'gamma': 'auto', 'C': 7.7426...  0.978832   0.978880
# 316   {'n_estimators': 250, 'min_samples_split': 5, ...  0.963504   0.963608
# 485   {'weights': 'uniform', 'n_neighbors': 13, 'met...  0.983140   0.983346
# 486   {'kernel': 'rbf', 'gamma': 'auto', 'C': 7.7426...  0.989463   0.989495
# 487   {'n_estimators': 200, 'min_samples_split': 2, ...  0.986301   0.986402
# 656   {'weights': 'uniform', 'n_neighbors': 9, 'metr...  0.930556   0.931432
# 657   {'kernel': 'rbf', 'gamma': 'scale', 'C': 2.154...  0.968567   0.968587
# 658   {'n_estimators': 200, 'min_samples_split': 5, ...  0.940058   0.940171
# 827   {'weights': 'distance', 'n_neighbors': 11, 'me...  0.954728   0.957251
# 828   {'kernel': 'rbf', 'gamma': 'auto', 'C': 7.7426...  0.978873   0.979199
# 829   {'n_estimators': 150, 'min_samples_split': 2, ...  0.964789   0.964834
# 998   {'weights': 'uniform', 'n_neighbors': 9, 'metr...  0.983384   0.983426
# 999   {'kernel': 'linear', 'gamma': 'scale', 'C': 0....  0.989426   0.989431
# 1000  {'n_estimators': 200, 'min_samples_split': 2, ...  0.978852   0.979141
#
#         Recall  F1-score  CV_scores(5fold)
# 111   0.891269  0.890733          0.904992
# 112   0.940692  0.940683          0.949658
# 113   0.912685  0.912613          0.920418
# 314   0.945985  0.945966          0.954676
# 315   0.978832  0.978830          0.985612
# 316   0.963504  0.963504          0.966547
# 485   0.983140  0.983134          0.981287
# 486   0.989463  0.989461          0.988040
# 487   0.986301  0.986298          0.979728
# 656   0.930556  0.930376          0.933018
# 657   0.968567  0.968572          0.972992
# 658   0.940058  0.940083          0.937698
# 827   0.954728  0.954659          0.948912
# 828   0.978873  0.978869          0.970736
# 829   0.964789  0.964787          0.951886
# 998   0.983384  0.983385          0.968734
# 999   0.989426  0.989426          0.989580
# 1000  0.978852  0.978854          0.972460

# %%
def create_result(group, feature_type):
    fea = group.get_group(feature_type).pivot_table(index=["Rice Seed"], columns=["Model"], values="Accuracy")
    tmp_df = pd.DataFrame(fea)
    mean_vals = fea.loc[:, :].mean()
    mean_mdl = pd.DataFrame([mean_vals.tolist()], columns=fea.columns, index=["AVERAGE"])
    return pd.concat((tmp_df, mean_mdl), axis=0)

# %%
create_result(group_feature, "Basic+Enhanced Color+Zernike moments+LBP+GLCM+Edge")
# Out:
# Model      K-Nearest Neighbors  Random Forest  Support Vector Machine
# BC-15                 0.894563       0.913509                0.944811
# Huongthom             0.950365       0.963504                0.979562
# Nep87                 0.984194       0.985248                0.986301
# Q5                    0.949698       0.965795                0.971831
# Thien_uu              0.981873       0.980363                0.984894
# Xi23                  0.937865       0.942251                0.972953
# AVERAGE               0.949760       0.958445                0.973392

# %%
create_result(group_feature, "Enhanced Color+Zernike moments+LBP+GLCM+Edge")
# Out:
# Model      K-Nearest Neighbors  Random Forest  Support Vector Machine
# BC-15                 0.887974       0.895387                0.944811
# Huongthom             0.953285       0.962774                0.977372
# Nep87                 0.984194       0.986301                0.987355
# Q5                    0.944668       0.963783                0.971831
# Thien_uu              0.975831       0.981873                0.987915
# Xi23                  0.923246       0.936404                0.968567
# AVERAGE               0.944866       0.954420                0.972975

# %%
create_result(group_feature, "Basic+Enhanced Color+Zernike moments")
# Out:
# Model      K-Nearest Neighbors  Random Forest  Support Vector Machine
# BC-15                 0.887974       0.915980                0.943987
# Huongthom             0.943066       0.961314                0.974453
# Nep87                 0.983140       0.986301                0.985248
# Q5                    0.948692       0.962777                0.977867
# Thien_uu              0.986405       0.981873                0.978852
# Xi23                  0.925439       0.945906                0.971491
# AVERAGE               0.945786       0.959025                0.971983

# %%
create_result(group_feature, "Basic+Enhanced Color+Zernike moments+LBP+GLCM")
# Out:
# Model      K-Nearest Neighbors  Random Forest  Support Vector Machine
# BC-15                 0.906919       0.910214                0.939868
# Huongthom             0.954745       0.956204                0.981022
# Nep87                 0.982086       0.985248                0.986301
# Q5                    0.953722       0.962777                0.970825
# Thien_uu              0.974320       0.975831                0.983384
# Xi23                  0.933480       0.936404                0.969298
# AVERAGE               0.950879       0.954446                0.971783

# %%
create_result(group_feature, "Basic+Enhanced Color+Zernike moments+LBP+GLCM+Edge")
# Out:
# Model      K-Nearest Neighbors  Random Forest  Support Vector Machine
# BC-15                 0.894563       0.913509                0.944811
# Huongthom             0.950365       0.963504                0.979562
# Nep87                 0.984194       0.985248                0.986301
# Q5                    0.949698       0.965795                0.971831
# Thien_uu              0.981873       0.980363                0.984894
# Xi23                  0.937865       0.942251                0.972953
# AVERAGE               0.949760       0.958445                0.973392

# %%
create_result(group_feature, "Basic GLCM GIST")
# Out:
# Model           KNN        RF       SVM
# BC-15      0.751236  0.864909  0.895387
# HuongThom  0.830657  0.891241  0.951825
# Nep87      0.874605  0.970495  0.959958
# Q5         0.788732  0.914487  0.897384
# ThienUu    0.910876  0.956193  0.938066
# Xi-23      0.910876  0.956193  0.938066
# AVERAGE    0.844497  0.925587  0.930115

# %%
create_result(group_feature, "Basic LBP GIST")
# Out:
# Model           KNN        RF       SVM
# BC-15      0.748764  0.876442  0.897035
# HuongThom  0.820438  0.872993  0.917518
# Nep87      0.856691  0.967334  0.947313
# Q5         0.783702  0.913481  0.903421
# ThienUu    0.913897  0.957704  0.942598
# Xi-23      0.913897  0.957704  0.942598
# AVERAGE    0.839565  0.924276  0.925080

# %%
create_result(group_feature, "Basic Gist")
# Out:
# Model           KNN        RF       SVM
# BC-15      0.723229  0.871499  0.886326
# HuongThom  0.816058  0.860584  0.917518
# Nep87      0.870390  0.973656  0.961012
# Q5         0.788732  0.913481  0.887324
# ThienUu    0.909366  0.960725  0.942598
# Xi-23      0.909366  0.960725  0.942598
# AVERAGE    0.836190  0.923445  0.922896

# %%
create_result(group_feature, "LBP")
# Out:
# Model           KNN        RF       SVM
# BC-15      0.584843  0.584020  0.618616
# HuongThom  0.632117  0.667883  0.675182
# Nep87      0.702845  0.735511  0.772392
# Q5         0.587525  0.574447  0.610664
# ThienUu    0.765861  0.802115  0.805136
# Xi-23      0.765861  0.802115  0.805136
# AVERAGE    0.673175  0.694348  0.714521

# %%
create_result(group_feature, "GLCM")
# Out:
# Model           KNN        RF       SVM
# BC-15      0.690280  0.727348  0.734761
# HuongThom  0.853285  0.837226  0.872263
# Nep87      0.926238  0.930453  0.950474
# Q5         0.684105  0.704225  0.744467
# ThienUu    0.802115  0.829305  0.868580
# Xi-23      0.802115  0.829305  0.868580
# AVERAGE    0.793023  0.809644  0.839854

# %%
create_result(group_feature, "Gist")
# Out:
# Model           KNN        RF       SVM
# BC-15      0.623558  0.817133  0.757002
# HuongThom  0.668613  0.844526  0.799270
# Nep87      0.720759  0.929399  0.900948
# Q5         0.588531  0.745473  0.721328
# ThienUu    0.803625  0.919940  0.891239
# Xi-23      0.803625  0.919940  0.891239
# AVERAGE    0.701452  0.862735  0.826838

# %%
create_result(group_feature, "Gist GLCM")
# Out:
# Model           KNN        RF       SVM
# BC-15      0.649918  0.787479  0.767710
# HuongThom  0.759854  0.878832  0.866423
# Nep87      0.809273  0.938883  0.934668
# Q5         0.640845  0.798793  0.753521
# ThienUu    0.845921  0.925982  0.929003
# Xi-23      0.845921  0.925982  0.929003
# AVERAGE    0.758622  0.875992  0.863388

# %%
create_result(group_feature, "LBP Gist")
# Out:
# Model           KNN        RF       SVM
# BC-15      0.659802  0.817957  0.780066
# HuongThom  0.690511  0.865693  0.802190
# Nep87      0.733404  0.926238  0.910432
# Q5         0.608652  0.749497  0.747485
# ThienUu    0.864048  0.933535  0.912387
# Xi-23      0.864048  0.933535  0.912387
# AVERAGE    0.736744  0.871076  0.844158

# %%
create_result(group_feature, "LBP GLCM")
# Out:
# Model           KNN        RF       SVM
# BC-15      0.694399  0.734761  0.757002
# HuongThom  0.834307  0.864234  0.885401
# Nep87      0.911486  0.933614  0.970495
# Q5         0.702213  0.714286  0.761569
# ThienUu    0.788520  0.835347  0.864048
# Xi-23      0.788520  0.835347  0.864048
# AVERAGE    0.786574  0.819598  0.850427

# %%
create_result(group_feature, "LBP GIST GLCM")
# Out:
# Model           KNN        RF       SVM
# BC-15      0.681219  0.816310  0.796540
# HuongThom  0.756204  0.893431  0.875182
# Nep87      0.814542  0.934668  0.947313
# Q5         0.663984  0.796781  0.780684
# ThienUu    0.867069  0.933535  0.930514
# Xi-23      0.867069  0.933535  0.930514
# AVERAGE    0.775015  0.884710  0.876791
