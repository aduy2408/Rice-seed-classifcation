# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("ran_model.csv")
cols = df.columns
cols
# Out:
# Index(['Model', 'Dataset', 'Feature Combination', 'Accuracy', 'Precision',
#        'Recall', 'F1 Score', 'CV_scores(5fold)'],
#       dtype='object')

# %%
df
# Out:
#                        Model Dataset  \
# 0        K-Nearest Neighbors   BC-15
# 1     Support Vector Machine   BC-15
# 2              Random Forest   BC-15
# 3        K-Nearest Neighbors   BC-15
# 4     Support Vector Machine   BC-15
# ...                      ...     ...
# 3424  Support Vector Machine   TH3-5
# 3425           Random Forest   TH3-5
# 3426     K-Nearest Neighbors   TH3-5
# 3427  Support Vector Machine   TH3-5
# 3428           Random Forest   TH3-5
#
#                                     Feature Combination  Accuracy  Precision  \
# 0                                                 Basic    0.8396     0.8467
# 1                                                 Basic    0.8695     0.8706
# 2                                                 Basic    0.8509     0.8512
# 3                                        Enhanced Color    0.8163     0.8171
# 4                                        Enhanced Color    0.8848     0.8848
# ...                                                 ...       ...        ...
# 3424  Enhanced Color+Zernike moments+LBP+GLCM+Edge+E...    0.9489     0.9498
# 3425  Enhanced Color+Zernike moments+LBP+GLCM+Edge+E...    0.9358     0.9360
# 3426  Basic+Enhanced Color+Zernike moments+LBP+GLCM+...    0.9095     0.9154
# 3427  Basic+Enhanced Color+Zernike moments+LBP+GLCM+...    0.9577     0.9582
# 3428  Basic+Enhanced Color+Zernike moments+LBP+GLCM+...    0.9489     0.9490
#
#       Recall  F1 Score  CV_scores(5fold)
# 0     0.8396    0.8392            0.8149
# 1     0.8695    0.8695            0.8360
# 2     0.8509    0.8509            0.8324
# 3     0.8163    0.8163            0.8197
# 4     0.8848    0.8848            0.8781
# ...      ...       ...               ...
# 3424  0.9489    0.9489            0.9475
# 3425  0.9358    0.9358            0.9237
# 3426  0.9095    0.9093            0.9021
# 3427  0.9577    0.9577            0.9496
# 3428  0.9489    0.9489            0.9194
#
# [3429 rows x 8 columns]

# %%
# df1 = pd.read_csv("/home/duyle/Rice_photos/features_extracted/moments/new_data_test_bc-15.csv")
# df2 = pd.read_csv("/home/duyle/Rice_photos/features_extracted/moments/new_data_test_huong_thom.csv")
# df3 = pd.read_csv("/home/duyle/Rice_photos/features_extracted/moments/new_data_test_nep87.csv")
# df4 = pd.read_csv("/home/duyle/Rice_photos/features_extracted/moments/new_data_test_q-5.csv")
# df5 = pd.read_csv("/home/duyle/Rice_photos/features_extracted/moments/new_data_test_tbr-36.csv")
# df6 = pd.read_csv("/home/duyle/Rice_photos/features_extracted/moments/new_data_test_tbr-45.csv")
# df7 = pd.read_csv("/home/duyle/Rice_photos/features_extracted/moments/new_data_test_th3-5.csv")
# df9 = pd.read_csv("/home/duyle/Rice_photos/features_extracted/moments/new_data_test_Thien_uu-8.csv")
# df10 = pd.read_csv("/home/duyle/Rice_photos/features_extracted/moments/new_data_test_Xi-23.csv")
# # Concatenate and drop duplicates
# merged_df = pd.concat([df1, df2,df3,df4,df5,df6,df7,df9,df10])

# # Save to file
# merged_df.to_csv("merged.csv", index=False)

# %%
best_combinations = df.loc[df.groupby("Rice Seed")["CV_scores(5fold)"].idxmax()]

# %%
best_combinations
# Out:
#                        Model     Rice Seed  \
# 361   Support Vector Machine         BC-15
# 724   Support Vector Machine  Huong_thom-1
# 892   Support Vector Machine        Nep-87
# 1450  Support Vector Machine           Q-5
# 2662  Support Vector Machine        TBR-36
# 2860  Support Vector Machine        TBR-45
# 3415  Support Vector Machine         TH3-5
# 1891  Support Vector Machine    Thien_uu-8
# 2272  Support Vector Machine         Xi-23
#
#                                                 Feature  Accuracy  Precision  \
# 361   Basic+Enhanced Color+Zernike moments+LBP+GLCM+...    0.9662     0.9662
# 724       Enhanced Color+Zernike moments+LBP+GLCM+Edge2    0.9263     0.9275
# 892                  Enhanced Color+Zernike moments+LBP    0.9820     0.9821
# 1450    Basic+Enhanced Color+Zernike moments+GLCM+Edge2    0.9547     0.9547
# 2662  Enhanced Color+Zernike moments+LBP+GLCM+Edge+E...    0.9649     0.9655
# 2860          Basic+Enhanced Color+Zernike moments+GLCM    0.9106     0.9120
# 3415  Basic+Enhanced Color+Zernike moments+GLCM+Edge...    0.9577     0.9584
# 1891  Basic+Enhanced Color+Zernike moments+GLCM+Edge...    0.9683     0.9683
# 2272  Basic+Enhanced Color+Zernike moments+GLCM+Edge...    0.9431     0.9431
#
#       Recall  F1-score  CV_scores(5fold)
# 361   0.9662    0.9662            0.9595
# 724   0.9263    0.9263            0.9353
# 892   0.9820    0.9820            0.9891
# 1450  0.9547    0.9547            0.9531
# 2662  0.9649    0.9649            0.9596
# 2860  0.9106    0.9106            0.9125
# 3415  0.9577    0.9577            0.9561
# 1891  0.9683    0.9683            0.9752
# 2272  0.9431    0.9431            0.9328

# %%
df
# Out:
#                        Model Dataset  \
# 0        K-Nearest Neighbors   BC-15
# 1     Support Vector Machine   BC-15
# 2              Random Forest   BC-15
# 3        K-Nearest Neighbors   BC-15
# 4     Support Vector Machine   BC-15
# ...                      ...     ...
# 3424  Support Vector Machine   TH3-5
# 3425           Random Forest   TH3-5
# 3426     K-Nearest Neighbors   TH3-5
# 3427  Support Vector Machine   TH3-5
# 3428           Random Forest   TH3-5
#
#                                     Feature Combination  Accuracy  Precision  \
# 0                                                 Basic    0.8396     0.8467
# 1                                                 Basic    0.8695     0.8706
# 2                                                 Basic    0.8509     0.8512
# 3                                        Enhanced Color    0.8163     0.8171
# 4                                        Enhanced Color    0.8848     0.8848
# ...                                                 ...       ...        ...
# 3424  Enhanced Color+Zernike moments+LBP+GLCM+Edge+E...    0.9489     0.9498
# 3425  Enhanced Color+Zernike moments+LBP+GLCM+Edge+E...    0.9358     0.9360
# 3426  Basic+Enhanced Color+Zernike moments+LBP+GLCM+...    0.9095     0.9154
# 3427  Basic+Enhanced Color+Zernike moments+LBP+GLCM+...    0.9577     0.9582
# 3428  Basic+Enhanced Color+Zernike moments+LBP+GLCM+...    0.9489     0.9490
#
#       Recall  F1 Score  CV_scores(5fold)
# 0     0.8396    0.8392            0.8149
# 1     0.8695    0.8695            0.8360
# 2     0.8509    0.8509            0.8324
# 3     0.8163    0.8163            0.8197
# 4     0.8848    0.8848            0.8781
# ...      ...       ...               ...
# 3424  0.9489    0.9489            0.9475
# 3425  0.9358    0.9358            0.9237
# 3426  0.9095    0.9093            0.9021
# 3427  0.9577    0.9577            0.9496
# 3428  0.9489    0.9489            0.9194
#
# [3429 rows x 8 columns]

# %%
df = df.rename(columns={'Feature Combination':'Feature','Dataset':'Rice Seed','F1 Score':'F1-score'})

# %%
feature = df["Feature"].unique()
feature
# Out:
# array(['Basic', 'Enhanced Color', 'Zernike moments', 'LBP', 'GLCM',
#        'Edge', 'Edge2', 'Basic+Enhanced Color', 'Basic+Zernike moments',
#        'Basic+LBP', 'Basic+GLCM', 'Basic+Edge', 'Basic+Edge2',
#        'Enhanced Color+Zernike moments', 'Enhanced Color+LBP',
#        'Enhanced Color+GLCM', 'Enhanced Color+Edge',
#        'Enhanced Color+Edge2', 'Zernike moments+LBP',
#        'Zernike moments+GLCM', 'Zernike moments+Edge',
#        'Zernike moments+Edge2', 'LBP+GLCM', 'LBP+Edge', 'LBP+Edge2',
#        'GLCM+Edge', 'GLCM+Edge2', 'Edge+Edge2',
#        'Basic+Enhanced Color+Zernike moments', 'Basic+Enhanced Color+LBP',
#        'Basic+Enhanced Color+GLCM', 'Basic+Enhanced Color+Edge',
#        'Basic+Enhanced Color+Edge2', 'Basic+Zernike moments+LBP',
#        'Basic+Zernike moments+GLCM', 'Basic+Zernike moments+Edge',
#        'Basic+Zernike moments+Edge2', 'Basic+LBP+GLCM', 'Basic+LBP+Edge',
#        'Basic+LBP+Edge2', 'Basic+GLCM+Edge', 'Basic+GLCM+Edge2',
#        'Basic+Edge+Edge2', 'Enhanced Color+Zernike moments+LBP',
#        'Enhanced Color+Zernike moments+GLCM',
#        'Enhanced Color+Zernike moments+Edge',
#        'Enhanced Color+Zernike moments+Edge2', 'Enhanced Color+LBP+GLCM',
#        'Enhanced Color+LBP+Edge', 'Enhanced Color+LBP+Edge2',
#        'Enhanced Color+GLCM+Edge', 'Enhanced Color+GLCM+Edge2',
#        'Enhanced Color+Edge+Edge2', 'Zernike moments+LBP+GLCM',
#        'Zernike moments+LBP+Edge', 'Zernike moments+LBP+Edge2',
#        'Zernike moments+GLCM+Edge', 'Zernike moments+GLCM+Edge2',
#        'Zernike moments+Edge+Edge2', 'LBP+GLCM+Edge', 'LBP+GLCM+Edge2',
#        'LBP+Edge+Edge2', 'GLCM+Edge+Edge2',
#        'Basic+Enhanced Color+Zernike moments+LBP',
#        'Basic+Enhanced Color+Zernike moments+GLCM',
#        'Basic+Enhanced Color+Zernike moments+Edge',
#        'Basic+Enhanced Color+Zernike moments+Edge2',
#        'Basic+Enhanced Color+LBP+GLCM', 'Basic+Enhanced Color+LBP+Edge',
#        'Basic+Enhanced Color+LBP+Edge2', 'Basic+Enhanced Color+GLCM+Edge',
#        'Basic+Enhanced Color+GLCM+Edge2',
#        'Basic+Enhanced Color+Edge+Edge2',
#        'Basic+Zernike moments+LBP+GLCM', 'Basic+Zernike moments+LBP+Edge',
#        'Basic+Zernike moments+LBP+Edge2',
#        'Basic+Zernike moments+GLCM+Edge',
#        'Basic+Zernike moments+GLCM+Edge2',
#        'Basic+Zernike moments+Edge+Edge2', 'Basic+LBP+GLCM+Edge',
#        'Basic+LBP+GLCM+Edge2', 'Basic+LBP+Edge+Edge2',
#        'Basic+GLCM+Edge+Edge2', 'Enhanced Color+Zernike moments+LBP+GLCM',
#        'Enhanced Color+Zernike moments+LBP+Edge',
#        'Enhanced Color+Zernike moments+LBP+Edge2',
#        'Enhanced Color+Zernike moments+GLCM+Edge',
#        'Enhanced Color+Zernike moments+GLCM+Edge2',
#        'Enhanced Color+Zernike moments+Edge+Edge2',
#        'Enhanced Color+LBP+GLCM+Edge', 'Enhanced Color+LBP+GLCM+Edge2',
#        'Enhanced Color+LBP+Edge+Edge2', 'Enhanced Color+GLCM+Edge+Edge2',
#        'Zernike moments+LBP+GLCM+Edge', 'Zernike moments+LBP+GLCM+Edge2',
#        'Zernike moments+LBP+Edge+Edge2',
#        'Zernike moments+GLCM+Edge+Edge2', 'LBP+GLCM+Edge+Edge2',
#        'Basic+Enhanced Color+Zernike moments+LBP+GLCM',
#        'Basic+Enhanced Color+Zernike moments+LBP+Edge',
#        'Basic+Enhanced Color+Zernike moments+LBP+Edge2',
#        'Basic+Enhanced Color+Zernike moments+GLCM+Edge',
#        'Basic+Enhanced Color+Zernike moments+GLCM+Edge2',
#        'Basic+Enhanced Color+Zernike moments+Edge+Edge2',
#        'Basic+Enhanced Color+LBP+GLCM+Edge',
#        'Basic+Enhanced Color+LBP+GLCM+Edge2',
#        'Basic+Enhanced Color+LBP+Edge+Edge2',
#        'Basic+Enhanced Color+GLCM+Edge+Edge2',
#        'Basic+Zernike moments+LBP+GLCM+Edge',
#        'Basic+Zernike moments+LBP+GLCM+Edge2',
#        'Basic+Zernike moments+LBP+Edge+Edge2',
#        'Basic+Zernike moments+GLCM+Edge+Edge2',
#        'Basic+LBP+GLCM+Edge+Edge2',
#        'Enhanced Color+Zernike moments+LBP+GLCM+Edge',
#        'Enhanced Color+Zernike moments+LBP+GLCM+Edge2',
#        'Enhanced Color+Zernike moments+LBP+Edge+Edge2',
#        'Enhanced Color+Zernike moments+GLCM+Edge+Edge2',
#        'Enhanced Color+LBP+GLCM+Edge+Edge2',
#        'Zernike moments+LBP+GLCM+Edge+Edge2',
#        'Basic+Enhanced Color+Zernike moments+LBP+GLCM+Edge',
#        'Basic+Enhanced Color+Zernike moments+LBP+GLCM+Edge2',
#        'Basic+Enhanced Color+Zernike moments+LBP+Edge+Edge2',
#        'Basic+Enhanced Color+Zernike moments+GLCM+Edge+Edge2',
#        'Basic+Enhanced Color+LBP+GLCM+Edge+Edge2',
#        'Basic+Zernike moments+LBP+GLCM+Edge+Edge2',
#        'Enhanced Color+Zernike moments+LBP+GLCM+Edge+Edge2',
#        'Basic+Enhanced Color+Zernike moments+LBP+GLCM+Edge+Edge2'],
#       dtype=object)

# %%
group_feature = df.groupby("Feature")

# %%
group_feature.get_group("Basic+Zernike moments+Edge2")
# Out:
#                        Model     Rice Seed                      Feature  \
# 108      K-Nearest Neighbors         BC-15  Basic+Zernike moments+Edge2
# 109   Support Vector Machine         BC-15  Basic+Zernike moments+Edge2
# 110            Random Forest         BC-15  Basic+Zernike moments+Edge2
# 489      K-Nearest Neighbors  Huong_thom-1  Basic+Zernike moments+Edge2
# 490   Support Vector Machine  Huong_thom-1  Basic+Zernike moments+Edge2
# 491            Random Forest  Huong_thom-1  Basic+Zernike moments+Edge2
# 870      K-Nearest Neighbors        Nep-87  Basic+Zernike moments+Edge2
# 871   Support Vector Machine        Nep-87  Basic+Zernike moments+Edge2
# 872            Random Forest        Nep-87  Basic+Zernike moments+Edge2
# 1251     K-Nearest Neighbors           Q-5  Basic+Zernike moments+Edge2
# 1252  Support Vector Machine           Q-5  Basic+Zernike moments+Edge2
# 1253           Random Forest           Q-5  Basic+Zernike moments+Edge2
# 1632     K-Nearest Neighbors    Thien_uu-8  Basic+Zernike moments+Edge2
# 1633  Support Vector Machine    Thien_uu-8  Basic+Zernike moments+Edge2
# 1634           Random Forest    Thien_uu-8  Basic+Zernike moments+Edge2
# 2013     K-Nearest Neighbors         Xi-23  Basic+Zernike moments+Edge2
# 2014  Support Vector Machine         Xi-23  Basic+Zernike moments+Edge2
# 2015           Random Forest         Xi-23  Basic+Zernike moments+Edge2
# 2394     K-Nearest Neighbors        TBR-36  Basic+Zernike moments+Edge2
# 2395  Support Vector Machine        TBR-36  Basic+Zernike moments+Edge2
# 2396           Random Forest        TBR-36  Basic+Zernike moments+Edge2
# 2775     K-Nearest Neighbors        TBR-45  Basic+Zernike moments+Edge2
# 2776  Support Vector Machine        TBR-45  Basic+Zernike moments+Edge2
# 2777           Random Forest        TBR-45  Basic+Zernike moments+Edge2
# 3156     K-Nearest Neighbors         TH3-5  Basic+Zernike moments+Edge2
# 3157  Support Vector Machine         TH3-5  Basic+Zernike moments+Edge2
# 3158           Random Forest         TH3-5  Basic+Zernike moments+Edge2
#
#       Accuracy  Precision  Recall  F1-score  CV_scores(5fold)
# 108     0.8380     0.8578  0.8380    0.8363            0.8209
# 109     0.9243     0.9243  0.9243    0.9242            0.9166
# 110     0.8961     0.8964  0.8961    0.8961            0.8678
# 489     0.8049     0.8157  0.8049    0.8037            0.8032
# 490     0.8533     0.8540  0.8533    0.8533            0.8405
# 491     0.8274     0.8274  0.8274    0.8274            0.8232
# 870     0.9535     0.9548  0.9535    0.9535            0.9698
# 871     0.9620     0.9627  0.9620    0.9620            0.9734
# 872     0.9472     0.9474  0.9472    0.9472            0.9667
# 1251    0.8940     0.8955  0.8940    0.8940            0.9001
# 1252    0.9270     0.9276  0.9270    0.9270            0.9232
# 1253    0.9124     0.9125  0.9124    0.9124            0.9039
# 1632    0.9524     0.9526  0.9524    0.9525            0.9482
# 1633    0.9597     0.9598  0.9597    0.9596            0.9581
# 1634    0.9568     0.9568  0.9568    0.9568            0.9581
# 2013    0.8690     0.8744  0.8690    0.8688            0.8546
# 2014    0.9292     0.9292  0.9292    0.9292            0.9182
# 2015    0.8988     0.8990  0.8988    0.8988            0.8820
# 2394    0.8674     0.8882  0.8674    0.8660            0.8332
# 2395    0.9259     0.9266  0.9259    0.9259            0.9089
# 2396    0.9012     0.9013  0.9012    0.9012            0.8954
# 2775    0.7720     0.7955  0.7720    0.7684            0.7623
# 2776    0.8316     0.8342  0.8316    0.8315            0.8134
# 2777    0.8212     0.8255  0.8212    0.8209            0.7911
# 3156    0.8920     0.8941  0.8920    0.8919            0.8683
# 3157    0.9168     0.9173  0.9168    0.9168            0.9136
# 3158    0.8905     0.8906  0.8905    0.8905            0.8855

# %%
def create_result(group, feature_type):
    fea = group.get_group(feature_type).pivot_table(index=["Rice Seed"], columns=["Model"], values="Accuracy")
    tmp_df = pd.DataFrame(fea)
    mean_vals = fea.loc[:, :].mean()
    mean_mdl = pd.DataFrame([mean_vals.tolist()], columns=fea.columns, index=["AVERAGE"])
    return pd.concat((tmp_df, mean_mdl), axis=0)

# %%
create_result(group_feature, "Basic+Enhanced Color+Zernike moments+LBP+Edge2")
# Out:
# Model         K-Nearest Neighbors  Random Forest  Support Vector Machine
# BC-15                    0.884800       0.948400                0.962100
# Huong_thom-1             0.856100       0.888400                0.924900
# Nep-87                   0.956700       0.970400                0.981000
# Q-5                      0.923200       0.936300                0.952400
# TBR-36                   0.894700       0.938900                0.957100
# TBR-45                   0.852300       0.878200                0.905400
# TH3-5                    0.915300       0.941600                0.956200
# Thien_uu-8               0.943800       0.958200                0.965400
# Xi-23                    0.881600       0.920000                0.939800
# AVERAGE                  0.900944       0.931156                0.949367

# %%
create_result(group_feature, "Basic+Enhanced Color+Skewness and Kurtosis+Hu moments+LBP+GLCM")
# Out:
# Model       K-Nearest Neighbors  Random Forest  Support Vector Machine
# BC-15                  0.888496       0.931858                0.946018
# Huong_thom             0.823860       0.867368                0.917895
# Nep-87                 0.927750       0.952700                0.967250
# Q-5                    0.897800       0.924700                0.943200
# TBR-45                 0.832900       0.862700                0.904100
# TH3-5                  0.877400       0.906600                0.937200
# Thien_uu-8             0.928000       0.940900                0.959700
# Xi-23                  0.870100       0.888100                0.913900
# AVERAGE                0.880788       0.909366                0.936158

# %%
create_result(group_feature, "Basic+Enhanced Color+Skewness and Kurtosis+Zernike moments+LBP+GLCM")
# Out:
# Model       K-Nearest Neighbors  Random Forest  Support Vector Machine
# BC-15                  0.892035       0.924779                0.958407
# Huong_thom             0.833684       0.871579                0.914386
# Nep-87                 0.929050       0.955700                0.972200
# Q-5                    0.926300       0.928600                0.949300
# TBR-45                 0.842000       0.870500                0.906700
# TH3-5                  0.905100       0.927000                0.946000
# Thien_uu-8             0.946700       0.953900                0.966900
# Xi-23                  0.884200       0.882600                0.921000
# AVERAGE                0.894884       0.914332                0.941862

# %%
create_result(group_feature, "Enhanced Color+Zernike moments+LBP+GLCM+Edge")
# Out:
# Model      K-Nearest Neighbors  Random Forest  Support Vector Machine
# BC-15                 0.887974       0.895387                0.944811
# Huongthom             0.953285       0.962774                0.977372
# Nep87                 0.984194       0.986301                0.987355
# Q5                    0.944668       0.963783                0.971831
# Thien_uu              0.975831       0.981873                0.987915
# Xi23                  0.923246       0.936404                0.968567
# AVERAGE               0.944866       0.954420                0.972975

# %%
create_result(group_feature, "Basic+Enhanced Color+Zernike moments")
# Out:
# Model      K-Nearest Neighbors  Random Forest  Support Vector Machine
# BC-15                 0.887974       0.915980                0.943987
# Huongthom             0.943066       0.961314                0.974453
# Nep87                 0.983140       0.986301                0.985248
# Q5                    0.948692       0.962777                0.977867
# Thien_uu              0.986405       0.981873                0.978852
# Xi23                  0.925439       0.945906                0.971491
# AVERAGE               0.945786       0.959025                0.971983

# %%
create_result(group_feature, "Basic+Enhanced Color+Zernike moments+LBP+GLCM")
# Out:
# Model      K-Nearest Neighbors  Random Forest  Support Vector Machine
# BC-15                 0.906919       0.910214                0.939868
# Huongthom             0.954745       0.956204                0.981022
# Nep87                 0.982086       0.985248                0.986301
# Q5                    0.953722       0.962777                0.970825
# Thien_uu              0.974320       0.975831                0.983384
# Xi23                  0.933480       0.936404                0.969298
# AVERAGE               0.950879       0.954446                0.971783

# %%
create_result(group_feature, "Basic+Enhanced Color+Zernike moments+LBP+GLCM+Edge")
# Out:
# Model      K-Nearest Neighbors  Random Forest  Support Vector Machine
# BC-15                 0.894563       0.913509                0.944811
# Huongthom             0.950365       0.963504                0.979562
# Nep87                 0.984194       0.985248                0.986301
# Q5                    0.949698       0.965795                0.971831
# Thien_uu              0.981873       0.980363                0.984894
# Xi23                  0.937865       0.942251                0.972953
# AVERAGE               0.949760       0.958445                0.973392

# %%
create_result(group_feature, "Basic GLCM GIST")
# Out:
# Model           KNN        RF       SVM
# BC-15      0.751236  0.864909  0.895387
# HuongThom  0.830657  0.891241  0.951825
# Nep87      0.874605  0.970495  0.959958
# Q5         0.788732  0.914487  0.897384
# ThienUu    0.910876  0.956193  0.938066
# Xi-23      0.910876  0.956193  0.938066
# AVERAGE    0.844497  0.925587  0.930115

# %%
create_result(group_feature, "Basic LBP GIST")
# Out:
# Model           KNN        RF       SVM
# BC-15      0.748764  0.876442  0.897035
# HuongThom  0.820438  0.872993  0.917518
# Nep87      0.856691  0.967334  0.947313
# Q5         0.783702  0.913481  0.903421
# ThienUu    0.913897  0.957704  0.942598
# Xi-23      0.913897  0.957704  0.942598
# AVERAGE    0.839565  0.924276  0.925080

# %%
create_result(group_feature, "Basic Gist")
# Out:
# Model           KNN        RF       SVM
# BC-15      0.723229  0.871499  0.886326
# HuongThom  0.816058  0.860584  0.917518
# Nep87      0.870390  0.973656  0.961012
# Q5         0.788732  0.913481  0.887324
# ThienUu    0.909366  0.960725  0.942598
# Xi-23      0.909366  0.960725  0.942598
# AVERAGE    0.836190  0.923445  0.922896

# %%
create_result(group_feature, "LBP")
# Out:
# Model           KNN        RF       SVM
# BC-15      0.584843  0.584020  0.618616
# HuongThom  0.632117  0.667883  0.675182
# Nep87      0.702845  0.735511  0.772392
# Q5         0.587525  0.574447  0.610664
# ThienUu    0.765861  0.802115  0.805136
# Xi-23      0.765861  0.802115  0.805136
# AVERAGE    0.673175  0.694348  0.714521

# %%
create_result(group_feature, "GLCM")
# Out:
# Model           KNN        RF       SVM
# BC-15      0.690280  0.727348  0.734761
# HuongThom  0.853285  0.837226  0.872263
# Nep87      0.926238  0.930453  0.950474
# Q5         0.684105  0.704225  0.744467
# ThienUu    0.802115  0.829305  0.868580
# Xi-23      0.802115  0.829305  0.868580
# AVERAGE    0.793023  0.809644  0.839854

# %%
create_result(group_feature, "Gist")
# Out:
# Model           KNN        RF       SVM
# BC-15      0.623558  0.817133  0.757002
# HuongThom  0.668613  0.844526  0.799270
# Nep87      0.720759  0.929399  0.900948
# Q5         0.588531  0.745473  0.721328
# ThienUu    0.803625  0.919940  0.891239
# Xi-23      0.803625  0.919940  0.891239
# AVERAGE    0.701452  0.862735  0.826838

# %%
create_result(group_feature, "Gist GLCM")
# Out:
# Model           KNN        RF       SVM
# BC-15      0.649918  0.787479  0.767710
# HuongThom  0.759854  0.878832  0.866423
# Nep87      0.809273  0.938883  0.934668
# Q5         0.640845  0.798793  0.753521
# ThienUu    0.845921  0.925982  0.929003
# Xi-23      0.845921  0.925982  0.929003
# AVERAGE    0.758622  0.875992  0.863388

# %%
create_result(group_feature, "LBP Gist")
# Out:
# Model           KNN        RF       SVM
# BC-15      0.659802  0.817957  0.780066
# HuongThom  0.690511  0.865693  0.802190
# Nep87      0.733404  0.926238  0.910432
# Q5         0.608652  0.749497  0.747485
# ThienUu    0.864048  0.933535  0.912387
# Xi-23      0.864048  0.933535  0.912387
# AVERAGE    0.736744  0.871076  0.844158

# %%
create_result(group_feature, "LBP GLCM")
# Out:
# Model           KNN        RF       SVM
# BC-15      0.694399  0.734761  0.757002
# HuongThom  0.834307  0.864234  0.885401
# Nep87      0.911486  0.933614  0.970495
# Q5         0.702213  0.714286  0.761569
# ThienUu    0.788520  0.835347  0.864048
# Xi-23      0.788520  0.835347  0.864048
# AVERAGE    0.786574  0.819598  0.850427

# %%
create_result(group_feature, "LBP GIST GLCM")
# Out:
# Model           KNN        RF       SVM
# BC-15      0.681219  0.816310  0.796540
# HuongThom  0.756204  0.893431  0.875182
# Nep87      0.814542  0.934668  0.947313
# Q5         0.663984  0.796781  0.780684
# ThienUu    0.867069  0.933535  0.930514
# Xi-23      0.867069  0.933535  0.930514
# AVERAGE    0.775015  0.884710  0.876791
