# %%
import itertools
import pandas as pd
import numpy as np
from tqdm import tqdm  # Progress tracking
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from itertools import combinations
from sklearn.ensemble import RandomForestClassifier

# %%
datasets = ['BC-15','Huongthom', 'Nep87','Q5','Thien_uu','Xi23']

# %%
df = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/all_with_zernike_pluscolor_enahnced_edge_BC-15.csv')

# %%
basic_features = ["area", "length", "width", "ratio", "major_axis_length", "minor_axis_length", "convex_hull_area",
                  "convex_hull_perimeter","mean_r","mean_g","mean_b","red_sqr","green_sqr","blue_sqr","texture_mean",
                  "texture_std","texture_uniformity","texture_third_moment"]
enhanced_color_features = ['mean_h','mean_s','mean_v','std_h','std_s','std_v','hue_sqr','sat_sqr',
'val_sqr','mean_y','mean_cr','mean_cb','std_y','std_cr','std_cb','y_sqr','cr_sqr','cb_sqr',
'mean_l','mean_a','mean_b','std_l','std_a','std_b_lab','l_sqr','a_sqr','b_lab_sqr']

zernike_features = [col for col in df.columns if col.startswith("zernike_")]
color_features = [col for col in df.columns if col.startswith("csd_")]
lbp_features = [col for col in df.columns if col.startswith("LBP_")]
glcm_features = [col for col in df.columns if col.startswith("GLCM_")]
gist_features = [col for col in df.columns if col.startswith("GIST_")]
edge_features = [col for col in df.columns if col.startswith("edge_energy")]

# %%
# Feature group dictionary
feature_groups = {
    "Basic": basic_features,
    "Enhanced Color": enhanced_color_features,
    "Zernike moments": zernike_features,
    "LBP": lbp_features,
    "GLCM": glcm_features,
    # "GIST": gist_features,
    "Edge":edge_features
}

# Generate all feature combinations
feature_combinations = []
for r in range(2, len(feature_groups) + 1):  # Start from 2 instead of 1
    for combo in itertools.combinations(feature_groups.keys(), r):
        feature_combinations.append(combo)

# %%
# Define models and their hyperparameter search spaces
param_distributions = {
    "K-Nearest Neighbors": {
        "n_neighbors": np.arange(1, 70, 2),
        "weights": ["uniform", "distance"],
        "metric": ["euclidean", "manhattan"]
    },
    "Support Vector Machine": {
        "C": np.logspace(-3, 2, 10),
        "kernel": ["linear", "rbf", "poly", "sigmoid"],
        "gamma": ["scale", "auto"]
    },
    "Random Forest": {
        "n_estimators": [100, 150, 200, 250,300],
        "max_depth": [10, 20, 30, None],
        "min_samples_split": [2, 5, 10],
        "min_samples_leaf": [1, 2, 4],
        "bootstrap": [True, False]
    }
}

# Define models
models = {
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Support Vector Machine": SVC(),
    "Random Forest": RandomForestClassifier()
}

# %%
all_results = []

# %%
# Store results


# Loop through each dataset
for dataset in tqdm(datasets, desc="Processing Datasets"):
    # Load dataset
    df = pd.read_csv(f'/content/drive/MyDrive/ColabNotebooks/all_with_zernike_pluscolor_enahnced_edge_{dataset}.csv')

    # Loop through each feature combination
    for feature_combo in tqdm(feature_combinations,desc=f"Feature Combos for {dataset}", leave=False):
        selected_features = []

        # Combine selected feature groups
        for group in feature_combo:
            selected_features.extend(feature_groups[group])
        df_selected = df[selected_features + ["Label"]]
        # Split dataset
        X = df_selected.drop(columns=['Label'])
        y = df_selected['Label']

        # Normalize features
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)

        # Train-test split
        X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.33, random_state=42, stratify=y)

        # Loop through models with progress tracking
        for name, model in tqdm(models.items(), desc=f"Training Models for {dataset} - {feature_combo}", leave=False):

            # Hyperparameter tuning with RandomizedSearchCV
            random_search = RandomizedSearchCV(
                model,
                param_distributions[name],
                n_iter=20,
                scoring='accuracy',
                cv=5,
                verbose=0,
                random_state=42,
                n_jobs=-1
            )

            # Perform search
            random_search.fit(X_train, y_train)

            # Get best model and parameters
            best_model = random_search.best_estimator_
            best_params = random_search.best_params_

            # Make predictions
            y_pred = best_model.predict(X_test)

            # Compute evaluation metrics
            accuracy = accuracy_score(y_test, y_pred)
            precision = precision_score(y_test, y_pred, average='weighted')
            recall = recall_score(y_test, y_pred, average='weighted')
            f1 = f1_score(y_test, y_pred, average='weighted')
            cv_scores = cross_val_score(best_model, X_train, y_train, cv=5, scoring='accuracy')

            # Save results
            all_results.append({
                "Model": name,
                "Dataset": dataset,
                "Feature Combination": "+".join(feature_combo),
                "Best Params": best_params,
                "Accuracy": accuracy,
                "Precision": precision,
                "Recall": recall,
                "F1 Score": f1,
                "CV_scores(5fold)": np.mean(cv_scores)
            })
# Out:
# Processing Datasets:   0%|          | 0/5 [00:00<?, ?it/s]
# Feature Combos for Huongthom:   0%|          | 0/57 [00:00<?, ?it/s]
#
# Training Models for Huongthom - ('Basic', 'Enhanced Color'):   0%|          | 0/3 [00:00<?, ?it/s]
#
# Training Models for Huongthom - ('Basic', 'Enhanced Color'):  33%|███▎      | 1/3 [00:08<00:16,  8.39s/it]
#
# Training Models for Huongthom - ('Basic', 'Enhanced Color'):  67%|██████▋   | 2/3 [00:28<00:15, 15.28s/it]
#
# Training Models for Huongthom - ('Basic', 'Enhanced Color'): 100%|██████████| 3/3 [04:42<00:00, 124.16s/it]
#
#
# Feature Combos for Huongthom:   2%|▏         | 1/57 [04:42<4:23:26, 282.25s/it]
#
# Training Models for Huongthom - ('Basic', 'Zernike moments'):   0%|          | 0/3 [00:00<?, ?it/s]
#
# Training Models for Huongthom - ('Basic', 'Zernike moments'):  33%|███▎      | 1/3 [00:04<00:09,  4.89s/it]
#
# Training Models for Huongthom - ('Basic', 'Zernike moments'):  67%|██████▋   | 2/3 [00:30<00:16, 16.93s/it]
#
# Training Models for Huongthom - ('Basic', 'Zernike moments'): 100%|██████████| 3/3 [04:58<00:00, 131.67s/it]
#
#
# Feature Combos for Huongthom:   4%|▎         | 2/57 [09:40<4:27:29, 291.81s/it]
#
# Training Models for Huongthom - ('Basic', 'LBP'):   0%|          | 0/3 [00:00<?, ?it/s]
#
# Training Models for Huongthom - ('Basic', 'LBP'):  33%|███▎      | 1/3 [00:03<00:07,  3.61s/it]
#
# Training Models for Huongthom - ('Basic', 'LBP'):  67%|██████▋   | 2/3 [00:30<00:17, 17.15s/it]
#
# Training Models for Huongthom - ('Basic', 'LBP'): 100%|██████████| 3/3 [04:21<00:00, 114.91s/it]
#
#
# Feature Combos for Huongthom:   5%|▌         | 3/57 [14:02<4:10:10, 277.98s/it]
#
# Training Models for Huongthom - ('Basic', 'GLCM'):   0%|          | 0/3 [00:00<?, ?it/s]
#
# Training Models for Huongthom - ('Basic', 'GLCM'):  33%|███▎      | 1/3 [00:03<00:07,  3.68s/it]
#
# Training Models for Huongthom - ('Basic', 'GLCM'):  67%|██████▋   | 2/3 [00:23<00:13, 13.00s/it]
#
# Training Models for Huongthom - ('Basic', 'GLCM'): 100%|██████████| 3/3 [04:33<00:00, 121.56s/it]
#
#
# Feature Combos for Huongthom:   7%|▋         | 4/57 [18:36<4:04:09, 276.41s/it]
#
# Training Models for Huongthom - ('Basic', 'Edge'):   0%|          | 0/3 [00:00<?, ?it/s]
#
# Training Models for Huongthom - ('Basic', 'Edge'):  33%|███▎      | 1/3 [00:04<00:08,  4.02s/it]
#
# Training Models for Huongthom - ('Basic', 'Edge'):  67%|██████▋   | 2/3 [00:24<00:13, 13.54s/it]
#
# Training Models for Huongthom - ('Basic', 'Edge'): 100%|██████████| 3/3 [03:46<00:00, 99.77s/it]
#
#
# Feature Combos for Huongthom:   9%|▉         | 5/57 [22:22<3:44:00, 258.47s/it]
#
# Training Models for Huongthom - ('Enhanced Color', 'Zernike moments'):   0%|          | 0/3 [00:00<?, ?it/s]
#
# Training Models for Huongthom - ('Enhanced Color', 'Zernike moments'):  33%|███▎      | 1/3 [00:05<00:11,  5.56s/it]
#
# Training Models for Huongthom - ('Enhanced Color', 'Zernike moments'):  67%|██████▋   | 2/3 [00:21<00:11, 11.44s/it]
#
# Training Models for Huongthom - ('Enhanced Color', 'Zernike moments'): 100%|██████████| 3/3 [05:42<00:00, 152.91s/it]
#
#
# Feature Combos for Huongthom:  11%|█         | 6/57 [28:05<4:03:57, 287.01s/it]
#
# Training Models for Huongthom - ('Enhanced Color', 'LBP'):   0%|          | 0/3 [00:00<?, ?it/s]
#
# Training Models for Huongthom - ('Enhanced Color', 'LBP'):  33%|███▎      | 1/3 [00:04<00:08,  4.11s/it]
#
# Training Models for Huongthom - ('Enhanced Color', 'LBP'):  67%|██████▋   | 2/3 [00:20<00:11, 11.43s/it]
#
# Training Models for Huongthom - ('Enhanced Color', 'LBP'): 100%|██████████| 3/3 [04:21<00:00, 116.19s/it]
#
#
# Feature Combos for Huongthom:  12%|█▏        | 7/57 [32:26<3:52:14, 278.69s/it]
#
# Training Models for Huongthom - ('Enhanced Color', 'GLCM'):   0%|          | 0/3 [00:00<?, ?it/s]
#
# Training Models for Huongthom - ('Enhanced Color', 'GLCM'):  33%|███▎      | 1/3 [00:06<00:12,  6.28s/it]
#
# Training Models for Huongthom - ('Enhanced Color', 'GLCM'):  67%|██████▋   | 2/3 [00:26<00:14, 14.69s/it]
#
# Training Models for Huongthom - ('Enhanced Color', 'GLCM'): 100%|██████████| 3/3 [04:43<00:00, 124.96s/it]
#
#
# Feature Combos for Huongthom:  14%|█▍        | 8/57 [37:09<3:48:44, 280.09s/it]
#
# Training Models for Huongthom - ('Enhanced Color', 'Edge'):   0%|          | 0/3 [00:00<?, ?it/s]
#
# Training Models for Huongthom - ('Enhanced Color', 'Edge'):  33%|███▎      | 1/3 [00:03<00:07,  3.55s/it]
#
# Training Models for Huongthom - ('Enhanced Color', 'Edge'):  67%|██████▋   | 2/3 [00:16<00:08,  8.82s/it]
#
# Training Models for Huongthom - ('Enhanced Color', 'Edge'): 100%|██████████| 3/3 [03:56<00:00, 105.31s/it]
#
#
# Feature Combos for Huongthom:  16%|█▌        | 9/57 [41:06<3:33:06, 266.38s/it]
#
# Training Models for Huongthom - ('Zernike moments', 'LBP'):   0%|          | 0/3 [00:00<?, ?it/s]
#
# Training Models for Huongthom - ('Zernike moments', 'LBP'):  33%|███▎      | 1/3 [00:05<00:10,  5.48s/it]
#
# Training Models for Huongthom - ('Zernike moments', 'LBP'):  67%|██████▋   | 2/3 [00:39<00:22, 22.35s/it]
#
# Training Models for Huongthom - ('Zernike moments', 'LBP'): 100%|██████████| 3/3 [04:53<00:00, 128.22s/it]
#
#
# Feature Combos for Huongthom:  18%|█▊        | 10/57 [46:00<3:35:18, 274.87s/it]
#
# Training Models for Huongthom - ('Zernike moments', 'GLCM'):   0%|          | 0/3 [00:00<?, ?it/s]
#
# Training Models for Huongthom - ('Zernike moments', 'GLCM'):  33%|███▎      | 1/3 [00:04<00:08,  4.28s/it]
#
# Training Models for Huongthom - ('Zernike moments', 'GLCM'):  67%|██████▋   | 2/3 [00:35<00:20, 20.35s/it]
#
# Training Models for Huongthom - ('Zernike moments', 'GLCM'): 100%|██████████| 3/3 [06:05<00:00, 161.38s/it]
#
#
# Feature Combos for Huongthom:  19%|█▉        | 11/57 [52:05<3:51:54, 302.49s/it]
#
# Training Models for Huongthom - ('Zernike moments', 'Edge'):   0%|          | 0/3 [00:00<?, ?it/s]
#
# Training Models for Huongthom - ('Zernike moments', 'Edge'):  33%|███▎      | 1/3 [00:03<00:07,  3.70s/it]
#
# Training Models for Huongthom - ('Zernike moments', 'Edge'):  67%|██████▋   | 2/3 [00:36<00:20, 20.90s/it]
#
# Training Models for Huongthom - ('Zernike moments', 'Edge'): 100%|██████████| 3/3 [05:09<00:00, 135.83s/it]
#
#
# Feature Combos for Huongthom:  21%|██        | 12/57 [57:14<3:48:24, 304.55s/it]
#
# Training Models for Huongthom - ('LBP', 'GLCM'):   0%|          | 0/3 [00:00<?, ?it/s]
#
# Training Models for Huongthom - ('LBP', 'GLCM'):  33%|███▎      | 1/3 [00:03<00:06,  3.35s/it]
#
# Training Models for Huongthom - ('LBP', 'GLCM'):  67%|██████▋   | 2/3 [00:42<00:24, 24.69s/it]
#
# Training Models for Huongthom - ('LBP', 'GLCM'): 100%|██████████| 3/3 [05:03<00:00, 132.34s/it]
#
#
# Feature Combos for Huongthom:  23%|██▎       | 13/57 [1:02:17<3:43:05, 304.22s/it]
#
# Training Models for Huongthom - ('LBP', 'Edge'):   0%|          | 0/3 [00:00<?, ?it/s]
#
# Training Models for Huongthom - ('LBP', 'Edge'):  33%|███▎      | 1/3 [00:05<00:11,  5.91s/it]
#
# Training Models for Huongthom - ('LBP', 'Edge'):  67%|██████▋   | 2/3 [00:46<00:26, 26.27s/it]
#
# Training Models for Huongthom - ('LBP', 'Edge'): 100%|██████████| 3/3 [03:24<00:00, 86.44s/it]
#
#
# Feature Combos for Huongthom:  25%|██▍       | 14/57 [1:05:42<3:16:26, 274.11s/it]
#
# Training Models for Huongthom - ('GLCM', 'Edge'):   0%|          | 0/3 [00:00<?, ?it/s]
#
# Training Models for Huongthom - ('GLCM', 'Edge'):  33%|███▎      | 1/3 [00:03<00:06,  3.07s/it]
#
# Training Models for Huongthom - ('GLCM', 'Edge'):  67%|██████▋   | 2/3 [00:35<00:20, 20.25s/it]
#
# Training Models for Huongthom - ('GLCM', 'Edge'): 100%|██████████| 3/3 [04:08<00:00, 108.14s/it]
#
#
# Feature Combos for Huongthom:  26%|██▋       | 15/57 [1:09:50<3:06:23, 266.27s/it]
#
# Training Models for Huongthom - ('Basic', 'Enhanced Color', 'Zernike moments'):   0%|          | 0/3 [00:00<?, ?it/s]
#
# Training Models for Huongthom - ('Basic', 'Enhanced Color', 'Zernike moments'):  33%|███▎      | 1/3 [00:05<00:11,  5.76s/it]
#
# Training Models for Huongthom - ('Basic', 'Enhanced Color', 'Zernike moments'):  67%|██████▋   | 2/3 [00:22<00:12, 12.51s/it]
#
# Training Models for Huongthom - ('Basic', 'Enhanced Color', 'Zernike moments'): 100%|██████████| 3/3 [06:03<00:00, 162.25s/it]
#
#
# Feature Combos for Huongthom:  28%|██▊       | 16/57 [1:15:54<3:21:56, 295.54s/it]
#
# Training Models for Huongthom - ('Basic', 'Enhanced Color', 'LBP'):   0%|          | 0/3 [00:00<?, ?it/s]
#
# Training Models for Huongthom - ('Basic', 'Enhanced Color', 'LBP'):  33%|███▎      | 1/3 [00:04<00:09,  4.97s/it]
#
# Training Models for Huongthom - ('Basic', 'Enhanced Color', 'LBP'):  67%|██████▋   | 2/3 [00:28<00:15, 15.93s/it]
#
# Training Models for Huongthom - ('Basic', 'Enhanced Color', 'LBP'): 100%|██████████| 3/3 [05:08<00:00, 136.59s/it]
#
#
# Feature Combos for Huongthom:  30%|██▉       | 17/57 [1:21:02<3:19:40, 299.52s/it]
#
# Training Models for Huongthom - ('Basic', 'Enhanced Color', 'GLCM'):   0%|          | 0/3 [00:00<?, ?it/s]
#
# Training Models for Huongthom - ('Basic', 'Enhanced Color', 'GLCM'):  33%|███▎      | 1/3 [00:08<00:16,  8.38s/it]
#
# Training Models for Huongthom - ('Basic', 'Enhanced Color', 'GLCM'):  67%|██████▋   | 2/3 [00:32<00:17, 17.60s/it]
#
# Training Models for Huongthom - ('Basic', 'Enhanced Color', 'GLCM'): 100%|██████████| 3/3 [05:41<00:00, 150.48s/it]
#
#
# Feature Combos for Huongthom:  32%|███▏      | 18/57 [1:26:43<3:22:48, 312.01s/it]
#
# Training Models for Huongthom - ('Basic', 'Enhanced Color', 'Edge'):   0%|          | 0/3 [00:00<?, ?it/s]
#
# Training Models for Huongthom - ('Basic', 'Enhanced Color', 'Edge'):  33%|███▎      | 1/3 [00:05<00:10,  5.41s/it]
#
# Training Models for Huongthom - ('Basic', 'Enhanced Color', 'Edge'):  67%|██████▋   | 2/3 [00:23<00:12, 12.68s/it]

# %%
all_results_pd = pd.DataFrame(all_results)

# %%
all_results_pd
# Out:
#                       Model    Dataset    Feature Combination  \
# 0       K-Nearest Neighbors      BC-15   Basic+Enhanced Color
# 1    Support Vector Machine      BC-15   Basic+Enhanced Color
# 2             Random Forest      BC-15   Basic+Enhanced Color
# 3       K-Nearest Neighbors      BC-15  Basic+Zernike moments
# 4    Support Vector Machine      BC-15  Basic+Zernike moments
# ..                      ...        ...                    ...
# 198     K-Nearest Neighbors  Huongthom    Zernike moments+LBP
# 199  Support Vector Machine  Huongthom    Zernike moments+LBP
# 200           Random Forest  Huongthom    Zernike moments+LBP
# 201     K-Nearest Neighbors  Huongthom   Zernike moments+GLCM
# 202  Support Vector Machine  Huongthom   Zernike moments+GLCM
#
#                                            Best Params  Accuracy  Precision  \
# 0    {'weights': 'distance', 'n_neighbors': 11, 'me...  0.885502   0.892514
# 1    {'kernel': 'rbf', 'gamma': 'auto', 'C': 7.7426...  0.928336   0.929771
# 2    {'n_estimators': 200, 'min_samples_split': 2, ...  0.913509   0.914896
# 3    {'weights': 'distance', 'n_neighbors': 11, 'me...  0.878913   0.889295
# 4    {'kernel': 'rbf', 'gamma': 'scale', 'C': 2.154...  0.922570   0.924069
# ..                                                 ...       ...        ...
# 198  {'weights': 'distance', 'n_neighbors': 11, 'me...  0.862044   0.865409
# 199  {'kernel': 'rbf', 'gamma': 'auto', 'C': 7.7426...  0.897080   0.897572
# 200  {'n_estimators': 200, 'min_samples_split': 2, ...  0.878102   0.879262
# 201  {'weights': 'uniform', 'n_neighbors': 13, 'met...  0.885401   0.892186
# 202  {'kernel': 'rbf', 'gamma': 'auto', 'C': 7.7426...  0.922628   0.922840
#
#        Recall  F1 Score  CV_scores(5fold)
# 0    0.885502  0.885003          0.879820
# 1    0.928336  0.928280          0.927725
# 2    0.913509  0.913441          0.899307
# 3    0.878913  0.878119          0.876574
# 4    0.922570  0.922506          0.935038
# ..        ...       ...               ...
# 198  0.862044  0.861644          0.868705
# 199  0.897080  0.897027          0.900360
# 200  0.878102  0.877968          0.876259
# 201  0.885401  0.884815          0.889568
# 202  0.922628  0.922608          0.933094
#
# [203 rows x 9 columns]
